# %%
import requests
import pandas as pd

headers = {"Authorization": "token your_personal_access_token"}

# Function to fetch repositories for a given topic
def fetch_github_repositories(topic):
    url = f"https://api.github.com/search/repositories?q=topic:{topic}&sort=stars&order=desc"
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()['items']
    else:
        print(f"Failed to fetch data for {topic}: {response.status_code}")
        return []

# List of trending topics
topics = ['machine learning', 'data visualization', 'deep learning', 'natural language processing']

# Extracting data for each topic
repositories_data = []
for topic in topics:
    repositories_data.extend(fetch_github_repositories(topic))

# Converting to a Pandas DataFrame
df = pd.DataFrame(repositories_data)

# Select the fields you want to store
df_cleaned = df[['name', 'owner', 'description', 'html_url', 'language', 'created_at', 'updated_at', 'stargazers_count', 'forks_count', 'open_issues_count', 'license']]

# Clean the data
df_cleaned['owner'] = df_cleaned['owner'].apply(lambda x: x['login'])
df_cleaned['license'] = df_cleaned['license'].apply(lambda x: x['name'] if x else 'No License')
df_cleaned['created_at'] = pd.to_datetime(df_cleaned['created_at'])
df_cleaned['updated_at'] = pd.to_datetime(df_cleaned['updated_at'])

# Renaming columns for better readability
df_cleaned.columns = ['Repository_Name', 'Owner', 'Description', 'URL', 'Programming_Language', 'Creation_Date', 'Last_Updated_Date', 'Number_of_Stars', 'Number_of_Forks', 'Number_of_Open_Issues', 'License_Type']

# Save to CSV for easy access later
df_cleaned.to_csv('repositories_data.csv', index=False)

# Print the top 5 records
print(df_cleaned.head())
# Out:
#               Repository_Name         Owner  \
# 0  mit-deep-learning-book-pdf      janishar
# 1    machine-learning-mindmap      dformoso
# 2      rapping-neural-network  robbiebarrat
# 3    awesome-machine-learning    onmyway133
# 4                       DeepJ     calclavia
#
#                                          Description  \
# 0  MIT Deep Learning Book in PDF format (complete...
# 1  A mindmap summarising Machine Learning concept...
# 2  Rap song writing recurrent neural network trai...
# 3  🎰 A curated list of machine learning resources...
# 4  A deep learning model for style-specific music...
#
#                                                  URL Programming_Language  \
# 0  https://github.com/janishar/mit-deep-learning-...                 Java
# 1  https://github.com/dformoso/machine-learning-m...                 None
# 2  https://github.com/robbiebarrat/rapping-neural...               Python
# 3  https://github.com/onmyway133/awesome-machine-...                 None
# ...

# %%
df = pd.read_csv(r'C:\Users\sagar\Desktop\GIT_REPO_PROJECT\repositories_data.csv')
df
# Out:
#                 Repository_Name         Owner  \
# 0    mit-deep-learning-book-pdf      janishar
# 1      machine-learning-mindmap      dformoso
# 2        rapping-neural-network  robbiebarrat
# 3      awesome-machine-learning    onmyway133
# 4                         DeepJ     calclavia
# ..                          ...           ...
# 115              ctakes-website        apache
# 116                  playground   brotakovici
# 117          E-Commerce-Chatbot  odorizziAlex
# 118         nlpandtextanalytics     swetharam
# 119               assign-kd-sls         rrwen
#
#                                            Description  \
# 0    MIT Deep Learning Book in PDF format (complete...
# 1    A mindmap summarising Machine Learning concept...
# 2    Rap song writing recurrent neural network trai...
# 3    🎰 A curated list of machine learning resources...
# 4    A deep learning model for style-specific music...
# ..                                                 ...
# ...

# %%
df.isnull().sum()
# Out:
# Repository_Name          0
# Owner                    0
# Description              0
# URL                      0
# Programming_Language     0
# Creation_Date            0
# Last_Updated_Date        0
# Number_of_Stars          0
# Number_of_Forks          0
# Number_of_Open_Issues    0
# License_Type             0
# dtype: int64

# %%
df.dropna(subset=["Description", "Programming_Language"], inplace = True )

# %%
df.to_csv('Non_Nan_Repo.csv')

# %%
df.dtypes
# Out:
# Repository_Name                       object
# Owner                                 object
# Description                           object
# URL                                   object
# Programming_Language                  object
# Creation_Date            datetime64[ns, UTC]
# Last_Updated_Date        datetime64[ns, UTC]
# Number_of_Stars                        int64
# Number_of_Forks                        int64
# Number_of_Open_Issues                  int64
# License_Type                          object
# dtype: object

# %%
df["Creation_Date"] = pd.to_datetime(df["Creation_Date"])
df["Last_Updated_Date"] = pd.to_datetime(df["Last_Updated_Date"])

# %%
df.to_csv("repo_data.csv")

# %%
df.columns
# Out:
# Index(['Repository_Name', 'Owner', 'Description', 'URL',
#        'Programming_Language', 'Creation_Date', 'Last_Updated_Date',
#        'Number_of_Stars', 'Number_of_Forks', 'Number_of_Open_Issues',
#        'License_Type'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Repository_Name          0
# Owner                    0
# Description              0
# URL                      0
# Programming_Language     0
# Creation_Date            0
# Last_Updated_Date        0
# Number_of_Stars          0
# Number_of_Forks          0
# Number_of_Open_Issues    0
# License_Type             0
# dtype: int64

# %%
df.head()
# Out:
#               Repository_Name         Owner  \
# 0  mit-deep-learning-book-pdf      janishar
# 2      rapping-neural-network  robbiebarrat
# 4                       DeepJ     calclavia
# 5                  HungaBunga        ypeleg
# 6        practical-mlops-book         paiml
#
#                                          Description  \
# 0  MIT Deep Learning Book in PDF format (complete...
# 2  Rap song writing recurrent neural network trai...
# 4  A deep learning model for style-specific music...
# 5  HungaBunga: Brute-Force all sklearn models wit...
# 6          [Book-2021] Practical MLOps O'Reilly Book
#
#                                                  URL Programming_Language  \
# 0  https://github.com/janishar/mit-deep-learning-...                 Java
# 2  https://github.com/robbiebarrat/rapping-neural...               Python
# 4                 https://github.com/calclavia/DeepJ               Python
# 5               https://github.com/ypeleg/HungaBunga               Python
# ...
